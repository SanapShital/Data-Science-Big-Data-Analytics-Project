# %%
import pandas as pd
import numpy as np

#for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#for interactivity
from ipywidgets import interact

# %%
#Reading Dataset
df = pd.read_csv("Crop_recommendation.csv")

# %%
#Shape of Dataset:

print("Shape of Dataset:", df.shape)
# Out:
# Shape of Dataset: (2200, 8)

# %%
#Head of Dataset

df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
#There will be any missing value in dataset

df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#Crop present in dataset

df["label"].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
#Summary For All the Crops

print("Average Ratio of Nitrogen in Soil : {0:.2f}".format(df["N"].mean()))
print("Average Ratio of Phosphorous in Soil : {0:.2f}".format(df["P"].mean()))
print("Average Ratio of Potassium in Soil : {0:.2f}".format(df["K"].mean()))
print("Average Temperature in Celsius  : {0:.2f}".format(df["temperature"].mean()))
print("Average Relative Humidity  in % : {0:.2f}".format(df["humidity"].mean()))
print("Average PH value  of  Soil : {0:.2f}".format(df["ph"].mean()))
print("Average Rainfall  in mm : {0:.2f}".format(df["rainfall"].mean()))
# Out:
# Average Ratio of Nitrogen in Soil : 50.55
# Average Ratio of Phosphorous in Soil : 53.36
# Average Ratio of Potassium in Soil : 48.15
# Average Temperature in Celsius  : 25.62
# Average Relative Humidity  in % : 71.48
# Average PH value  of  Soil : 6.47
# Average Rainfall  in mm : 103.46

# %%
#Summary Statistics for each of Crops

@interact
def summary(crops=list(df["label"].value_counts().index)):
    x = df[df["label"] == crops]
    
    print("------------------------------------------------")
    print("Statistics for", crops)
    print("Minimum Nitrogen Required:", x["N"].min())
    print("Average Nitrogen Required:", x["N"].mean())
    print("Maximum Nitrogen Required:", x["N"].max())
    
    print("------------------------------------------------")
    print("Statistics for", crops)
    print("Minimum Phosphorous Required:", x["P"].min())
    print("Average Phosphorous Required:", x["P"].mean())
    print("Maximum Phosphorous Required:", x["P"].max())
    
    print("------------------------------------------------")
    print("Statistics for", crops)
    print("Minimum Potassium Required:", x["K"].min())
    print("Average Potassium Required:", x["K"].mean())
    print("Maximum Potassium Required:", x["K"].max())
    
    print("------------------------------------------------")
    print("Statistics for Temperature")
    print("Minimum Temperature Required:{0:.2f}".format(x["temperature"].min()))
    print("Average Temperature Required:{0:.2f}".format(x["temperature"].mean()))
    print("Maximum Temperature Required:{0:.2f}".format(x["temperature"].max()))
    
    print("------------------------------------------------")
    print("Statistics for Humidity")
    print("Minimum Humidity Required:{0:.2f}".format(x["humidity"].min()))
    print("Average Humidity Required:{0:.2f}".format(x["humidity"].mean()))
    print("Maximum Humidity Required:{0:.2f}".format(x["humidity"].max()))
    
    print("------------------------------------------------")
    print("Statistics for PH")
    print("Minimum PH Required:{0:.2f}".format(x["ph"].min()))
    print("Average PH Required:{0:.2f}".format(x["ph"].mean()))
    print("Maximum PH Required:{0:.2f}".format(x["ph"].max()))
 
    print("------------------------------------------------")
    print("Statistics for Rainfall")
    print("Minimum Rainfall Required:{0:.2f}".format(x["rainfall"].min()))
    print("Average Rainfall Required:{0:.2f}".format(x["rainfall"].mean()))
    print("Maximum Rainfall Required:{0:.2f}".format(x["rainfall"].max()))
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'maize', 'jute', 'cotton', 'coconut', 'pa…

# %%
# Average Requirement for each crop with average conditions

@interact
def compare(conditions=["N", "P", "K", "rainfall", "humidity", "ph", "temperature"]):
    print("Average Value For", conditions, "is {0:.2f}".format(df[conditions].mean()))
    print("-----------------------------------------------------------")
    
    print("Rice:{0:.2f}".format(df[(df["label"]=="rice")][conditions].mean()))
    print("maize:{0:.2f}".format(df[(df["label"]=="maize")][conditions].mean()))
    print("jute :{0:.2f}".format(df[(df["label"]=="jute ")][conditions].mean()))
    print("Cotton :{0:.2f}".format(df[(df["label"]=="cotton ")][conditions].mean()))
    print("Coffe:{0:.2f}".format(df[(df["label"]=="Coffee")][conditions].mean()))
    print("Mango:{0:.2f}".format(df[(df["label"]=="Mango")][conditions].mean()))
    print("Moth Beans:{0:.2f}".format(df[(df["label"]=="Moth Beans")][conditions].mean()))
    print("Pomegranate:{0:.2f}".format(df[(df["label"]=="Pomegranate")][conditions].mean()))
    print("Pigeon Peas:{0:.2f}".format(df[(df["label"]=="Pigeon Peas")][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'rainfall', 'humidity', 'ph',…

# %%
#Function More Intuitive

@interact
def compare(conditions=["N", "P", "K", "rainfall", "humidity", "ph", "temperature"]):
    print("Crop which require greater than average",conditions,'\n')
    print(df[df[conditions]>df[conditions].mean()]["label"].unique())
    print("-----------------------------")
    print("Crop which require greater than average",conditions,'\n')
    print(df[df[conditions]<=df[conditions].mean()]["label"].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'rainfall', 'humidity', 'ph',…

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 10))  # Set the overall figure size

plt.suptitle("Distribution of Agricultural Conditions", fontsize=16, y=1.05)  # Centered title

plt.subplot(2, 4, 1)
sns.distplot(df["N"], color="red")
plt.xlabel("Ratio of Nitrogen", fontsize=12)
plt.ylabel("Density", fontsize=12)  # Added y-label
plt.title("Distribution of Nitrogen", fontsize=14)  # Added title
plt.grid()

plt.subplot(2, 4, 2)
sns.distplot(df["P"], color="blue")
plt.xlabel("Ratio of Phosphorous", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("Distribution of Phosphorous", fontsize=14)
plt.grid()

plt.subplot(2, 4, 3)
sns.distplot(df["K"], color="black")
plt.xlabel("Ratio of Potassium", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("Distribution of Potassium", fontsize=14)
plt.grid()

plt.subplot(2, 4, 4)
sns.distplot(df["temperature"], color="grey")
plt.xlabel("Ratio of Temperature", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("Distribution of Temperature", fontsize=14)
plt.grid()

plt.subplot(2, 4, 5)
sns.distplot(df["humidity"], color="darkblue")
plt.xlabel("Ratio of Humidity", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("Distribution of Humidity", fontsize=14)
plt.grid()

plt.subplot(2, 4, 6)
sns.distplot(df["rainfall"], color="green")
plt.xlabel("Ratio of Rainfall", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("Distribution of Rainfall", fontsize=14)
plt.grid()

plt.subplot(2, 4, 7)
sns.distplot(df["ph"], color="pink")
plt.xlabel("Ratio of pH", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.title("Distribution of pH", fontsize=14)
plt.grid()

plt.tight_layout()  # Adjust the layout to prevent overlapping
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15320\2596560526.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["N"], color="red")
# C:\Users\dell\AppData\Local\Temp\ipykernel_15320\2596560526.py:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#find out some interesting facts

print("Some Interesting Patterns")
print("-----------------------")
print("Crops which require very High Ratio of Nitrogen content in Soil:",df[df["N"]>120]["label"].unique())
print("Crops which require very High Ratio of Phosphorous content in Soil:",df[df["P"]>100]["label"].unique())
print("Crops which require very High Ratio of Potassium content in Soil:",df[df["K"]>200]["label"].unique())
print("Crops which require very High Rainfall:",df[df["rainfall"]>200]["label"].unique())
print("Crops which require very High Temprature:",df[df["temperature"]>40]["label"].unique())
print("Crops which require very Low Temprature :",df[df["temperature"]<10]["label"].unique())
print("Crops which require very Low Humidity:",df[df["humidity"]<20]["label"].unique())
print("Crops which require very High PH:",df[df["ph"]>9]["label"].unique())
print("Crops which require very Low PH:",df[df["ph"]<4]["label"].unique())
# Out:
# Some Interesting Patterns
# -----------------------
# Crops which require very High Ratio of Nitrogen content in Soil: ['cotton']
# Crops which require very High Ratio of Phosphorous content in Soil: ['grapes' 'apple']
# Crops which require very High Ratio of Potassium content in Soil: ['grapes' 'apple']
# Crops which require very High Rainfall: ['rice' 'papaya' 'coconut']
# Crops which require very High Temprature: ['grapes' 'papaya']
# Crops which require very Low Temprature : ['grapes']
# Crops which require very Low Humidity: ['chickpea' 'kidneybeans']
# Crops which require very High PH: ['mothbeans']
# Crops which require very Low PH: ['mothbeans']

# %%
#Which crop only be grown in Summer,Winter,Rainy Season
print("Summer Crops")
print(df[(df["temperature"]>30)&(df["humidity"]>50)]["label"].unique())
print("-------------------------------------")

print("Winter Crops")
print(df[(df["temperature"]<20)&(df["humidity"]>30)]["label"].unique())
print("-------------------------------------")

print("Rainy Crops")
print(df[(df["rainfall"]>200)&(df["humidity"]>30)]["label"].unique())
print("-------------------------------------")
# Out:
# Summer Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# -------------------------------------
# Winter Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# -------------------------------------
# Rainy Crops
# ['rice' 'papaya' 'coconut']
# -------------------------------------

# %%
from sklearn.cluster import KMeans
#remove column label
x=df.drop(["label"],axis=1)

#Select all value of data
x=x.values

#shape
print(x.shape)
# Out:
# (2200, 7)

# %%
#determine optimum number of cluster within dataset

plt.rcParams["figure.figsize"]=(10,4)

wcss=[]
for i in range(1,11):
    km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)

#lets plot results
plt.plot(range(1,11),wcss)
plt.title("The Elbow Method ",fontsize=20)
plt.xlabel("No. of Clusters")
plt.ylabel("wcss")
plt.show()

# %%
#lets implement K Means to perform clustering analysis
km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means=km.fit_predict(x)
    
    #lets find out results
a=df["label"]
y_means=pd.DataFrame(y_means)
z=pd.concat([y_means,a],axis=1)
z=z.rename(columns={0:"cluster"})
#lets check the Cluster of each Crop

print("Lets check the results After applying the k Means Clustering Analysis \n")
print("Crop in First Cluster :",z[z['cluster']==0]["label"].unique())
print("-----------------------------------")

print("Crop in Second Cluster :",z[z['cluster']==1]["label"].unique())
print("-----------------------------------")

print("Crop in Third Cluster :",z[z['cluster']==2]["label"].unique())
print("-----------------------------------")

print("Crop in Fourth Cluster :",z[z['cluster']==3]["label"].unique())
print("-----------------------------------")
# Out:
# Lets check the results After applying the k Means Clustering Analysis
#
# Crop in First Cluster : ['pigeonpeas' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# -----------------------------------
# Crop in Second Cluster : ['chickpea']
# -----------------------------------
# Crop in Third Cluster : ['grapes' 'apple']
# -----------------------------------
# Crop in Fourth Cluster : ['maize' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean' 'blackgram'
#  'lentil' 'papaya']
# -----------------------------------

# %%
#lets split dataset for Predictive Modelling

y=df["label"]
x=df.drop(["label"],axis=1)

print("Shape of x:",x.shape)
print("Shape of y:",y.shape)
# Out:
# Shape of x: (2200, 7)
# Shape of y: (2200,)

# %%
#lets create for training and testing set for validation for results 
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

print("The shape of x train:",x_train.shape)
print("The shape of x train:",x_test.shape)
print("The shape of y train:",x_train.shape)
print("The shape of y train:",x_test.shape)
# Out:
# The shape of x train: (1760, 7)
# The shape of x train: (440, 7)
# The shape of y train: (1760, 7)
# The shape of y train: (440, 7)

# %%
#lets create Predictive Model

from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
# Out:
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#evaluate Model Performance

from sklearn.metrics import confusion_matrix

#Print confusion matrix
plt.rcParams["figure.figsize"]=(10,10)
cm=confusion_matrix(y_pred,y_test)
sns.heatmap(cm,annot=True,cmap="Wistia")
plt.title("Confusion Matrix for Logistic Regression",fontsize=15)
plt.show()

# %%
from sklearn.metrics import classification_report

# Assuming y_test and y_pred are your true and predicted labels respectively
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.86      0.82      0.84        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.89      1.00      0.94        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.84      1.00      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.94      0.94        17
#        maize       0.94      0.89      0.91        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.92      0.90        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
#head of dataset
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
prediction=model.predict((np.array([[90,40,40,20,80,7,200]])))
print("The Suggested Crop for Given Climatic Condition is :",prediction)
# Out:
# The Suggested Crop for Given Climatic Condition is : ['rice']
# C:\Users\dell\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
